# %% [markdown]
# # We installeren de nodige bibliotheken

# %% [markdown]
# ### Maak een .venv aan.
# - Menu : View | Command Pallet...
# - python: Create Environment...
# - Kies Venv | .venv - folder
# - Kies jou python versie

# %%
# %pip install tensorflow
# %pip install scikit-learn
# %pip install pandas
# %pip install opencv-python
# %pip install matplotlib
# %pip install numpy
