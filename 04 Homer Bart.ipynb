# %%
# Homer & Bart

# %%
import tensorflow as tf        
import matplotlib.pyplot as plt
import numpy as np
import cv2           
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
bestanden = [os.path.join(pad, f) for f in sorted(os.listdir(pad))]
print(bestanden)

# %%
for pad in bestanden:
  
  try:                             
    figuur = 
    (H, W) = figuur.shape[:2]        
  except:
    continue

  figuur = 
  figuur = 
  figuur = figuur.ravel()
  figuren.append(figuur)    
  
  figuurNaam = os.path.basename(os.path.normpath(pad))  
  if figuurNaam.startswith('b'):                             
    klasse = 0
  else:
    klasse = 1

  klassen.append(klasse)

# %%
figuur = cv2.imread('Data/homer_bart/bart1.bmp')
figuur = 
plt.imshow(figuur)
plt.show()

figuur = 
grijs = 
plt.imshow(grijs, cmap='gray')
plt.show()

# %%
X = np.asarray(figuren)
y = np.asarray(klassen)
X.shape, y.shape

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)  
X_train.shape, y_train.shape

# %%
print(X_test.shape, y_test.shape)
print(X.shape, y.shape)
print(128 * 128)
print((16384 + 2) / 2)

# %%
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='test accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
X[0].max(), X[0].min()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X[1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)  
X_train.shape, y_train.shape

# %%
plt.plot(historic.history['loss']);

# %%
plt.plot(historic.history['accuracy']);

# %%
voorspelling = network1.predict(X_test)  
voorspelling

# %%
# 0 False Bart
# 1 True Homer
voorspelling = (voorspelling > 0.5)
voorspelling

# %%
y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, voorspelling)
cm

# %%
plt.imshow(cm, cmap='BuPu')
plt.colorbar()

# Add annotations
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, str(cm[i, j]), ha='center', va='center')

plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, voorspelling))

# %%
image_test = X_test[10]  
image_test = scaler.inverse_transform(image_test.reshape(1, -1))
plt.show()

if network2.predict(image_test)[0][0] < 0.5:
  print('Bart')
else:
  print('Homer')

# %%
figuur = 
figuur = 
plt.imshow(figuur)
plt.show()

figuur = 
grijs =  
plt.imshow(grijs, cmap='gray')
plt.show()

image_test = grijs
image_test = scaler.inverse_transform(image_test.reshape(1, -1))

if network2.predict(image_test)[0][0] < 0.5:
  print('Bart')
else:
  print('Homer')
