# %%
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt
import numpy as np
# Maak een netwerk met 1 lineaire unit met 1 inputs

# %%
x = np.linspace(0, 15)
y = 2 * x + 3 

xs = np.array([0.0, 1.0, 2.0, 10.0], dtype=float)
ys = np.array([3.0, 5.0, 7.0, 23.0], dtype=float)

plt.plot(x, y, 'g-', label='y = 2x + 3')
plt.plot(xs, ys, 'ro', label='Data')
plt.legend()
plt.xlabel('x') 
plt.ylabel('y')
plt.title('Grafiek van y = 2x + 3 met data punten')
plt.show()

# %%
import matplotlib.pyplot as plt

x = np.linspace(0, 15)
y = 2 * x + 3 
plt.plot(x, y, 'g-', label='y = 2x + 3')

plt.plot(xs, ys, 'ro', label='Data')
plt.plot([3.0, 4.0, 8.0, 12.0], voorspel, 'bo', label='Voorspelling')
plt.legend()
plt.xlabel('x') 
plt.ylabel('y')
plt.title('Voorspelling met Neuraal Netwerk')
plt.show()
